# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv("https://www.datos.gov.co/api/views/mdb2-6f57/rows.csv?accessType=DOWNLOAD")
df=df[df["uni_med_"]==1]
df=df[df["año"]!=2023]

# %%
sns.violinplot(data=df,x="desc_serv_hosp",y="edad_")
# Out:
# <Axes: xlabel='desc_serv_hosp', ylabel='edad_'>

# %%
sns.boxplot(data=df,x="desc_serv_hosp",y="edad_")
# Out:
# <Axes: xlabel='desc_serv_hosp', ylabel='edad_'>

# %%
sns.kdeplot(data=df,x="edad_",hue="sexo_")
# Out:
# <Axes: xlabel='edad_', ylabel='Density'>

# %%
sns.histplot(data=df, x="sexo_")
# Out:
# <Axes: xlabel='sexo_', ylabel='Count'>

# %%
sns.kdeplot(data = df, x="semana", hue="Ciclo_de_vida")
# Out:
# <Axes: xlabel='semana', ylabel='Density'>

# %%
sns.histplot(data=df,x="Ciclo_de_vida")
# Out:
# <Axes: xlabel='Ciclo_de_vida', ylabel='Count'>

# %%
sns.boxplot(data = df, x="semana", y="COMUNA")
# Out:
# <Axes: xlabel='semana', ylabel='COMUNA'>

# %%
sns.histplot(data=df,x="año")
# Out:
# <Axes: xlabel='año', ylabel='Count'>

# %%
sns.histplot(data=df,x="semana")
# Out:
# <Axes: xlabel='semana', ylabel='Count'>

# %%
df.describe()
# Out:
#               semana            año          edad_  uni_med_       unidedad  \
# count  140788.000000  140788.000000  140788.000000  140788.0  140788.000000
# mean       23.302895    2020.982420      41.144686       1.0     139.096542
# std        14.191361       0.651326      18.196247       0.0      27.629139
# min         1.000000    2020.000000       0.000000       1.0      11.000000
# 25%        13.000000    2021.000000      27.000000       1.0     127.000000
# 50%        24.000000    2021.000000      39.000000       1.0     139.000000
# 75%        31.000000    2021.000000      54.000000       1.0     154.000000
# max        53.000000    2022.000000     113.000000       1.0    1113.000000
#
#            serv_hosp          orden
# count  140788.000000  140788.000000
# mean        4.039897   70519.054990
# std         0.240526   40731.698484
# min         2.000000       1.000000
# 25%         4.000000   35256.750000
# 50%         4.000000   70478.500000
# ...

# %%
df[df["edad_"]==113]
# Out:
#            fec_not  semana   año  edad_  uni_med_  unidedad Grupo_etario  \
# 123025  10/06/2021      24  2021    113         1      1113     70 y mas
#
#         Ciclo_de_vida nombre_nacionalidad sexo_ bar_ver_ NUMERO COMUNA  \
# 123025  Persona Mayor            COLOMBIA     M    MUTIS            17
#
#        NOMCOMUNA     COMUNA tip_ss_         NOMBRE EPS  serv_hosp  \
# 123025     MUTIS  17. MUTIS       P  FUERZAS MILITARES          4
#
#        desc_serv_hosp   orden
# 123025     Recuperado  123026
